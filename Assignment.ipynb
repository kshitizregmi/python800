# %% [markdown]
# # Class work: WAP to swap values between  two variables

# %%
num1 = 2.5
num2 = 0.36

# %%
tmp = num1

# %%
num1 = num2

# %%
num2 = tmp

# %%
num1
# Out:
# 0.36

# %%
num2
# Out:
# 2.5

# %%
num1 = 2.5
num2 = 0.36

# %%
num1 , num2 = num2, num1

# %%
num1
# Out:
# 0.36

# %%
num2
# Out:
# 2.5

# %%
num1 = 2.5
num2 = 0.36
print(f"num1 = {num2} and num2 = {num1}")
# Out:
# num1 = 0.36 and num2 = 2.5

# %%
num2
# Out:
# 0.36

# %%
num2 * 5
# Out:
# 1.7999999999999998

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sec = 42 * 60 + 42

# %%
sec
# Out:
# 2562

# %%
km = 10

# %%
in_miles = km/1.609

# %%
in_miles
# Out:
# 6.215040397762586

# %%
in_min = 42 + 42/60

# %%
s = in_miles/in_min

# %%
s
# Out:
# 0.1455512973714891

# %%
speed = in_miles/sec

# %%
speed
# Out:
# 0.0024258549561914852
